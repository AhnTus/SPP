# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import dataset

# %%
import pandas as pd

# %%
fptdf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/FPT.csv')
fptdf.drop('Open Interest', axis=1, inplace=True)
fptdf.head()
# Out:
#   Ticker        Date/Time   Open   High    Low  Close  Volume
# 0    FPT  12/25/2018 9:15  30.89  30.89  30.89  30.89   35410
# 1    FPT  12/25/2018 9:16  30.81  30.81  30.81  30.81     190
# 2    FPT  12/25/2018 9:17  30.74  30.81  30.74  30.74    1120
# 3    FPT  12/25/2018 9:18  30.74  30.74  30.74  30.74    2120
# 4    FPT  12/25/2018 9:19  30.74  30.74  30.74  30.74   22500

# %%
msndf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MSN.csv')
msndf.drop('Open Interest', axis=1, inplace=True)
msndf.head()
# Out:
#   Ticker        Date/Time  Open  High   Low  Close  Volume
# 0    MSN  12/25/2017 9:15  73.1  73.1  73.1   73.1    4210
# 1    MSN  12/25/2017 9:16  73.0  73.0  73.0   73.0    5000
# 2    MSN  12/25/2017 9:18  73.5  73.5  73.5   73.5     210
# 3    MSN  12/25/2017 9:20  73.2  73.5  73.1   73.1    2050
# 4    MSN  12/25/2017 9:21  73.0  73.0  73.0   73.0    1380

# %%
pnjdf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PNJ.csv')
pnjdf.drop('Open Interest', axis=1, inplace=True)
pnjdf.head()
# Out:
#   Ticker       Date/Time   Open   High    Low  Close  Volume
# 0    PNJ  2/28/2018 9:15  78.14  78.99  78.14  78.99     270
# 1    PNJ  2/28/2018 9:16  78.94  78.94  78.94  78.94      10
# 2    PNJ  2/28/2018 9:19  78.14  78.14  78.14  78.14     283
# 3    PNJ  2/28/2018 9:20  78.14  78.14  78.14  78.14     480
# 4    PNJ  2/28/2018 9:21  78.14  78.14  78.14  78.14     146

# %%
vicdf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/VIC.csv')
vicdf.drop('Open Interest', axis=1, inplace=True)
vicdf.head()
# Out:
#   Ticker        Date/Time  Open  High   Low  Close  Volume
# 0    VIC  10/17/2018 9:39  98.5  98.5  98.5   98.5     390
# 1    VIC  10/17/2018 9:40  98.5  98.5  98.5   98.5     760
# 2    VIC  10/17/2018 9:41  98.6  98.6  98.6   98.6    2060
# 3    VIC  10/17/2018 9:42  98.6  98.6  98.6   98.6    5540
# 4    VIC  10/17/2018 9:43  98.6  98.7  98.6   98.7     760

# %% [markdown]
# # Data Processing

# %%
def check(fptdf):
    l=[]
    columns=fptdf.columns
    for col in columns:
        dtypes=fptdf[col].dtypes
        nunique=fptdf[col].nunique()
        sum_null=fptdf[col].isnull().sum()
        l.append([col,dtypes,nunique,sum_null])
    df_check=pd.DataFrame(l)
    df_check.columns=['column','dtypes','nunique','sum_null']
    return df_check
check(fptdf)
# Out:
#       column   dtypes  nunique  sum_null
# 0     Ticker   object        1         0
# 1  Date/Time   object    97406         0
# 2       Open  float64      802         0
# 3       High  float64      800         0
# 4        Low  float64      802         0
# 5      Close  float64      802         0
# 6     Volume    int64     6221         0

# %%
fptdf['Date/Time'] = pd.to_datetime(fptdf['Date/Time'])
fptdf.set_index('Date/Time',inplace=True)
# fptdf.reset_index(inplace=True)

# %%
fptdf.describe().T.apply(lambda x: x.apply("{0:.3f}".format))
# Out:
#             count      mean        std     min      25%       50%       75%  \
# Open    97406.000    45.072      6.360  30.250   39.740    46.950    49.200
# High    97406.000    45.090      6.365  30.250   39.740    46.950    49.250
# Low     97406.000    45.051      6.354  30.220   39.700    46.950    49.170
# Close   97406.000    45.072      6.360  30.250   39.740    46.950    49.200
# Volume  97406.000  8044.173  17532.026  10.000  750.000  2960.000  8960.000
#
#                 max
# Open         58.400
# High         58.500
# Low          58.400
# Close        58.400
# Volume  1255930.000

# %%
def check(msndf):
    l=[]
    columns=msndf.columns
    for col in columns:
        dtypes=msndf[col].dtypes
        nunique=msndf[col].nunique()
        sum_null=msndf[col].isnull().sum()
        l.append([col,dtypes,nunique,sum_null])
    df_check=pd.DataFrame(l)
    df_check.columns=['column','dtypes','nunique','sum_null']
    return df_check
check(msndf)
# Out:
#       column   dtypes  nunique  sum_null
# 0     Ticker   object        1         0
# 1  Date/Time   object   135354         0
# 2       Open  float64     1110         0
# 3       High  float64     1094         0
# 4        Low  float64     1112         0
# 5      Close  float64     1111         0
# 6     Volume    int64     5316         0

# %%
msndf['Date/Time'] = pd.to_datetime(msndf['Date/Time'])
msndf.set_index('Date/Time',inplace=True)
# msndf.reset_index(inplace=True)

# %%
msndf.describe().T.apply(lambda x: x.apply("{0:.3f}".format))
# Out:
#              count      mean        std     min      25%       50%       75%  \
# Open    135354.000    74.879     15.418  46.500   57.900    79.100    86.000
# High    135354.000    74.932     15.427  46.500   57.900    79.200    86.100
# Low     135354.000    74.835     15.413  46.400   57.800    79.100    86.000
# Close   135354.000    74.881     15.419  46.400   57.800    79.100    86.000
# Volume  135354.000  5683.578  27985.133  10.000  500.000  2000.000  5560.000
#
#                 max
# Open        117.800
# High        118.000
# Low         117.700
# Close       118.000
# Volume  3300680.000

# %%
def check(pnjdf):
    l=[]
    columns=pnjdf.columns
    for col in columns:
        dtypes=pnjdf[col].dtypes
        nunique=pnjdf[col].nunique()
        sum_null=pnjdf[col].isnull().sum()
        l.append([col,dtypes,nunique,sum_null])
    df_check=pd.DataFrame(l)
    df_check.columns=['column','dtypes','nunique','sum_null']
    return df_check
check(pnjdf)
# Out:
#       column   dtypes  nunique  sum_null
# 0     Ticker   object        1         0
# 1  Date/Time   object   125309         0
# 2       Open  float64     2565         0
# 3       High  float64     2608         0
# 4        Low  float64     2423         0
# 5      Close  float64     2549         0
# 6     Volume    int64     4575         0

# %%
pnjdf['Date/Time'] = pd.to_datetime(pnjdf['Date/Time'])
pnjdf.set_index('Date/Time',inplace=True)
# pnjdf.reset_index(inplace=True)

# %%
pnjdf.describe().T.apply(lambda x: x.apply("{0:.3f}".format))
# Out:
#              count      mean       std     min      25%       50%       75%  \
# Open    125309.000    72.182     9.900  44.430   64.600    72.800    80.160
# High    125309.000    72.373     9.996  44.530   64.700    73.010    80.350
# Low     125309.000    72.042     9.831  44.040   64.570    72.640    80.060
# Close   125309.000    72.179     9.899  44.140   64.600    72.830    80.160
# Volume  125309.000  3031.830  7248.953   1.000  220.000  1000.000  3130.000
#
#                max
# Open       100.160
# High       100.160
# Low        100.160
# Close      100.160
# Volume  580730.000

# %%
def check(vicdf):
    l=[]
    columns=vicdf.columns
    for col in columns:
        dtypes=vicdf[col].dtypes
        nunique=vicdf[col].nunique()
        sum_null=vicdf[col].isnull().sum()
        l.append([col,dtypes,nunique,sum_null])
    df_check=pd.DataFrame(l)
    df_check.columns=['column','dtypes','nunique','sum_null']
    return df_check
check(vicdf)
# Out:
#       column   dtypes  nunique  sum_null
# 0     Ticker   object        1         0
# 1  Date/Time   object   101266         0
# 2       Open  float64      528         0
# 3       High  float64      526         0
# 4        Low  float64      532         0
# 5      Close  float64      530         0
# 6     Volume    int64     3296         0

# %%
vicdf['Date/Time'] = pd.to_datetime(vicdf['Date/Time'])
vicdf.set_index('Date/Time',inplace=True)
# vicdf.reset_index(inplace=True)

# %%
pnjdf.describe().T.apply(lambda x: x.apply("{0:.3f}".format))
# Out:
#              count      mean       std     min      25%       50%       75%  \
# Open    125309.000    72.182     9.900  44.430   64.600    72.800    80.160
# High    125309.000    72.373     9.996  44.530   64.700    73.010    80.350
# Low     125309.000    72.042     9.831  44.040   64.570    72.640    80.060
# Close   125309.000    72.179     9.899  44.140   64.600    72.830    80.160
# Volume  125309.000  3031.830  7248.953   1.000  220.000  1000.000  3130.000
#
#                max
# Open       100.160
# High       100.160
# Low        100.160
# Close      100.160
# Volume  580730.000

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

# %%
## Biểu đồ thể hiện giá đóng cửa
fig = plt.figure(figsize = (15,10))

plt.subplot(2, 2, 1)
plt.plot(fptdf['Close'], label='Close Price history',color='g')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('FPT Close Price')

plt.subplot(2, 2, 2)
plt.plot(msndf['Close'], label='Close Price history',color='r')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('MSN Close Price')

plt.subplot(2, 2, 3)
plt.plot(pnjdf['Close'], label='Close Price history',color='b')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('PNJ Close Price')

plt.subplot(2, 2, 4)
plt.plot(vicdf['Close'], label='Close Price history',color='y')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('VIC Close Price')
# Out:
# Text(0.5, 1.0, 'VIC Close Price')

# %%
# Tính tổng giá trị giao dịch cho mỗi ngày
daily_volume_fpt = fptdf.groupby(fptdf.index.date)['Volume'].sum()
daily_volume_msn = msndf.groupby(msndf.index.date)['Volume'].sum()
daily_volume_pnj = pnjdf.groupby(pnjdf.index.date)['Volume'].sum()
daily_volume_vic = vicdf.groupby(vicdf.index.date)['Volume'].sum()

# Vẽ biểu đồ
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

axes[0, 0].plot(daily_volume_fpt.index, daily_volume_fpt.values)
axes[0, 0].set_xlabel('Date')
axes[0, 0].set_ylabel('Volume')
axes[0, 0].set_title('FPT')

axes[0, 1].plot(daily_volume_msn.index, daily_volume_msn.values)
axes[0, 1].set_xlabel('Date')
axes[0, 1].set_ylabel('Volume')
axes[0, 1].set_title('MSN')

axes[1, 0].plot(daily_volume_pnj.index, daily_volume_pnj.values)
axes[1, 0].set_xlabel('Date')
axes[1, 0].set_ylabel('Volume')
axes[1, 0].set_title('PNJ')

axes[1, 1].plot(daily_volume_vic.index, daily_volume_vic.values)
axes[1, 1].set_xlabel('Date')
axes[1, 1].set_ylabel('Volume')
axes[1, 1].set_title('VIC')

plt.tight_layout()
plt.show()

# %%
#Biến động giá trong 60 ngày
fptdf['Price Change'] = fptdf['Close'].shift(-60) - fptdf['Close']
msndf['Price Change'] = msndf['Close'].shift(-60) - msndf['Close']
pnjdf['Price Change'] = pnjdf['Close'].shift(-60) - pnjdf['Close']
vicdf['Price Change'] = vicdf['Close'].shift(-60) - vicdf['Close']

# Vẽ biểu đồ
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

axes[0, 0].plot(fptdf.index, fptdf['Price Change'])
axes[0, 0].set_xlabel('Date')
axes[0, 0].set_ylabel('FPT stock price fluctuations')
axes[0, 0].set_title('FPT stock price fluctuations in 60days ')

axes[0, 1].plot(msndf.index, msndf['Price Change'])
axes[0, 1].set_xlabel('Date')
axes[0, 1].set_ylabel('MSN stock price fluctuations')
axes[0, 1].set_title('MSN stock price fluctuations in 60days ')

axes[1, 0].plot(pnjdf.index, pnjdf['Price Change'])
axes[1, 0].set_xlabel('Date')
axes[1, 0].set_ylabel('PNJ stock price fluctuations')
axes[1, 0].set_title('PNJ stock price fluctuations in 60days ')

axes[1, 1].plot(vicdf.index, vicdf['Price Change'])
axes[1, 1].set_xlabel('Date')
axes[1, 1].set_ylabel('VIC stock price fluctuations')
axes[1, 1].set_title('VIC stock price fluctuations in 60days ')

plt.tight_layout()
plt.show()

# %% [markdown]
# # LSTM

# %%
import math
data = fptdf.filter(['Close'])
fpt = data.values
training_data_len = math.ceil(len(fpt)*.8)
training_data_len
# Out:
# 77925

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(fpt)
scaled_data
# Out:
# array([[0.02273535],
#        [0.01989343],
#        [0.01740675],
#        ...,
#        [0.9928952 ],
#        [0.98934281],
#        [0.98934281]])

# %%
import numpy as np
# Create the training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()

# Convert the x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([0.02273535, 0.01989343, 0.01740675, 0.01740675, 0.01740675,
#        0.01740675, 0.01456483, 0.03055062, 0.03339254, 0.03339254,
#        0.03197158, 0.03055062, 0.03055062, 0.03055062, 0.03339254,
#        0.03339254, 0.03055062, 0.03445826, 0.03445826, 0.02806394,
#        0.02806394, 0.02522202, 0.02522202, 0.02522202, 0.02522202,
#        0.02273535, 0.02273535, 0.02522202, 0.02273535, 0.02273535,
#        0.02522202, 0.02522202, 0.02806394, 0.03339254, 0.03055062,
#        0.03197158, 0.03197158, 0.03055062, 0.03055062, 0.03055062,
#        0.03055062, 0.03339254, 0.03339254, 0.03339254, 0.03055062,
#        0.03055062, 0.03055062, 0.03055062, 0.03055062, 0.03197158,
#        0.03197158, 0.03055062, 0.03197158, 0.03055062, 0.03197158,
#        0.03055062, 0.03055062, 0.03055062, 0.03055062, 0.03055062])]
# [0.03197158081705154]
#
# [array([0.02273535, 0.01989343, 0.01740675, 0.01740675, 0.01740675,
#        0.01740675, 0.01456483, 0.03055062, 0.03339254, 0.03339254,
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=32, epochs=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 292s 118ms/step - loss: 0.0030
# Epoch 2/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 282s 116ms/step - loss: 2.4989e-04
# Epoch 3/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 279s 115ms/step - loss: 2.4866e-04
# Epoch 4/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 283s 116ms/step - loss: 2.4741e-04
# Epoch 5/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 322s 116ms/step - loss: 2.4462e-04
# Epoch 6/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 326s 118ms/step - loss: 2.3676e-04
# Epoch 7/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 319s 117ms/step - loss: 2.3597e-04
# Epoch 8/100
# 2434/2434 ━━━━━━━━━━━━━━━━━━━━ 288s 118ms/step - loss: 2.3015e-04
# Epoch 9/100
# ...

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = fpt[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)
print("RMSE: {:.4f}".format(rmse))
print("MAE: {:.4f}".format(mae))
print("MSE: {:.4f}".format(mse))
print("R2 Score: {:.4f}".format(r2))
# Out:
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step
# RMSE: 0.1460
# MAE: 0.1137
# MSE: 0.0213
# R2 Score: 0.9975

# %%
train = fptdf[:training_data_len]
val = fptdf[training_data_len:]
val['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close', fontsize=18)
plt.plot(train['Close'])
plt.plot(val[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-27-000c2ca2ac75>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val['Predictions'] = predictions

# %% [markdown]
# # ARIMA

# %%
# !pip install pmdarima
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.7 MB/s eta 0:00:00
# ...

# %%
from pmdarima import auto_arima
model = auto_arima(fpt, start_p=0, start_q=0,test='adf',
                      max_p=3, max_q=3, m=1,d=None,seasonal=False,
                      start_P=0, D=1, trace=True, # Parameters added to the function call
                      error_action='ignore',
                      suppress_warnings=True,
                      stepwise=True)
print(model.summary())
model.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-260655.242, Time=23.45 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-263642.366, Time=22.85 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-263583.033, Time=18.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-260655.356, Time=3.39 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-263645.767, Time=21.46 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-263656.783, Time=17.26 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-263657.826, Time=18.39 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-263642.205, Time=77.98 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-263673.711, Time=42.51 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-263667.200, Time=37.12 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-263686.053, Time=20.75 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-263672.154, Time=146.87 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-263685.509, Time=12.21 sec
#
# ...

# %%
import math
from statsmodels.tsa.arima.model import ARIMA
data = fptdf.filter(['Close'])
fpt = data.values
train_size = math.ceil(len(fpt)*.8)
train, test = fpt[0:train_size], fpt[train_size:]
model = ARIMA(train, order=(3,1,3))
model_fit = model.fit()
predictions = model_fit.forecast(len(test))
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close', fontsize=18)
plt.plot(train)
plt.plot(test)
plt.plot(predictions)
